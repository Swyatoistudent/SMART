# %% [markdown]
# # Task 1

# %% [markdown]
# ## data preparation

# %%
import pandas as pd

# %%
order_items_path = '/Users/sviat/Downloads/OneDrive_1_30-04-2024/S_Data/order_items.csv'
products_path = '/Users/sviat/Downloads/OneDrive_1_30-04-2024/S_Data/products.csv'
orders_path  = '/Users/sviat/Downloads/OneDrive_1_30-04-2024/S_Data/orders.csv'

# %%
order_items_ds = pd.read_csv(order_items_path)
products_ds = pd.read_csv(products_path)

# %%
order_items_ds
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
products_ds
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# All products category

# %%
products_category = products_ds['product_category_name'].unique()
products_category
# Out:
# array(['perfumaria', 'artes', 'esporte_lazer', 'bebes',
#        'utilidades_domesticas', 'instrumentos_musicais', 'cool_stuff',
#        'moveis_decoracao', 'eletrodomesticos', 'brinquedos',
#        'cama_mesa_banho', 'construcao_ferramentas_seguranca',
#        'informatica_acessorios', 'beleza_saude', 'malas_acessorios',
#        'ferramentas_jardim', 'moveis_escritorio', 'automotivo',
#        'eletronicos', 'fashion_calcados', 'telefonia', 'papelaria',
#        'fashion_bolsas_e_acessorios', 'pcs', 'casa_construcao',
#        'relogios_presentes', 'construcao_ferramentas_construcao',
#        'pet_shop', 'eletroportateis', 'agro_industria_e_comercio', nan,
#        'moveis_sala', 'sinalizacao_e_seguranca', 'climatizacao',
#        'consoles_games', 'livros_interesse_geral',
#        'construcao_ferramentas_ferramentas',
#        'fashion_underwear_e_moda_praia', 'fashion_roupa_masculina',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
# ...

# %%
df = order_items_ds.join(products_ds.set_index('product_id'),on='product_id')

# %%
df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# Top 10 products category by demand

# %%
category = df.groupby(['product_category_name']).product_category_name.count().reset_index(name='count')
category.index = category.product_category_name
category = category.drop(columns=['product_category_name'])
category = category.sort_values(by=['count'])
category[-10:].plot.bar()
# Out:
# <Axes: xlabel='product_category_name'>

# %%
df.drop(columns=['shipping_limit_date'])
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   order_id                    112650 non-null  object
#  1   order_item_id               112650 non-null  int64
#  2   product_id                  112650 non-null  object
#  3   seller_id                   112650 non-null  object
#  4   shipping_limit_date         112650 non-null  object
#  5   price                       112650 non-null  float64
#  6   freight_value               112650 non-null  float64
#  7   product_category_name       111047 non-null  object
#  8   product_name_lenght         111047 non-null  float64
#  9   product_description_lenght  111047 non-null  float64
#  10  product_photos_qty          111047 non-null  float64
#  11  product_weight_g            112632 non-null  float64
# ...

# %%
orders_ds = pd.read_csv(orders_path)
orders_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# droping all columns expect order id ,order approved_at

# %%
orders_ds = orders_ds[['order_id','order_approved_at']]

# %%
orders_ds = orders_ds.rename(columns={'order_approved_at':'date'})

# %%
orders_ds['date'] = pd.to_datetime(orders_ds['date'])
orders_ds['date'] = orders_ds['date'].dt.date
orders_ds['date'] = pd.to_datetime(orders_ds['date'])

# %%
orders_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  99441 non-null  object
#  1   date      99281 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.5+ MB

# %%
orders_ds
# Out:
#                                order_id       date
# 0      e481f51cbdc54678b7cc49136f2d6af7 2017-10-02
# 1      53cdb2fc8bc7dce0b6741e2150273451 2018-07-26
# 2      47770eb9100c2d0c44946d9cf07ec65d 2018-08-08
# 3      949d5b44dbf5de918fe9c16f97b45f8a 2017-11-18
# 4      ad21c59c0840e6cb83a9ceb5573f8159 2018-02-13
# ...                                 ...        ...
# 99436  9c5dedf39a927c1b2549525ed64a053c 2017-03-09
# 99437  63943bddc261676b46f01ca7ac2f7bd8 2018-02-06
# 99438  83c1379a015df1e13d02aae0204711ab 2017-08-27
# 99439  11c177c8e97725db2631073c19f07b62 2018-01-08
# 99440  66dea50a8b16d9b4dee7af250b4be1a5 2018-03-09
#
# [99441 rows x 2 columns]

# %%
df = df.join(orders_ds.set_index('order_id'),on='order_id')

# %%
df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# ## All products category time series analysis

# %%
all_cat_df  = df.groupby(['date']).date.count().reset_index(name='sales')

# %%
all_cat_df = all_cat_df[all_cat_df['date'].dt.year!=2016]

# %%
all_cat_df.columns=['date','sales']
# set data as index
all_cat_df.index = pd.to_datetime(all_cat_df['date'], format="%Y-%m-%d")

# remove data attribute that is repeated
all_cat_df.drop('date', axis=1, inplace=True)

# %%
all_cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 598 entries, 2017-01-05 to 2018-09-03
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sales   598 non-null    int64
# dtypes: int64(1)
# memory usage: 9.3 KB

# %%
from statsmodels.tsa.stattools import adfuller

# %%
all_cat_df = all_cat_df.resample('D').ffill()
X = all_cat_df.sales
result = adfuller(X)
print("ADF")
print("statisical test",result[0])
print('p-value',result[1])
# Out:
# ADF
# statisical test -3.0362035662002738
# p-value 0.03164899221149023

# %% [markdown]
# p-value<0.05 - time series is stationary

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
#moving avarage
ma = all_cat_df.rolling(30).mean()
fig,ax = plt.subplots(figsize=(10,5))
all_cat_df.plot(ax=ax,legend=False)
ma.plot(ax=ax,legend=False)
plt.tight_layout()

# %% [markdown]
# ## ARIMA

# %%
from pmdarima.arima import auto_arima

# %%
train = all_cat_df[:-50]
valid = all_cat_df[-50:]

# %%
all_cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 607 entries, 2017-01-05 to 2018-09-03
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sales   607 non-null    int64
# dtypes: int64(1)
# memory usage: 9.5 KB

# %%
model = auto_arima(train,suppress_warnings=True)
model.fit(train)
forecast = model.predict(n_periods=len(valid))
forecast = pd.DataFrame(forecast,index = valid.index,columns=['Prediction'])

# %%
forecast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50 entries, 2018-07-16 to 2018-09-03
# Freq: D
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prediction  50 non-null     float64
# dtypes: float64(1)
# memory usage: 800.0 bytes

# %%
fig,ax = plt.subplots(figsize=(10,5))
train.plot(ax=ax, c='#004a8f')
valid.plot(ax=ax, c='#91aac9')
forecast.plot(ax=ax,c='red',linewidth=1.8)
ax.legend(["train",'valid','arima'])
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,5))
valid.plot(ax=ax, c='#91aac9')
forecast.plot(ax=ax,c='red',linewidth=1.8)
ax.legend(['valid','arima'])
plt.show()

# %% [markdown]
# ### Prediction for next 7 days

# %%
model = auto_arima(all_cat_df,suppress_warnings=True)
model.fit(all_cat_df)
forecast = model.predict(n_periods=7)

# %%
fig,ax = plt.subplots(figsize=(10,5))
all_cat_df.plot(ax=ax, c='#004a8f')
forecast.plot(ax=ax,c='red',linewidth=1.8)
ax.legend(['train','arima'])
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,5))
forecast.plot(ax=ax,c='red',linewidth=1.8)
ax.legend(['arima'])
plt.show()

# %% [markdown]
# ## Feature engineering

# %%
def create_features(df,lab=None):
    df['day_of_week']=df['date'].dt.day_of_week
    df['quarter']=df.date.dt.quarter
    df['month']=df.date.dt.month
    df['year'] = df.date.dt.year
    df['dayofyear'] = df.date.dt.dayofyear
    df['dayofmonth'] = df.date.dt.day
    
    X = df[['day_of_week','quarter','month','year',
           'dayofyear','dayofmonth']]
    if lab is not None:
     return X,df[lab]
    return X

# %% [markdown]
# ## ML model(XGboost)

# %%
all_cat_df  = df.groupby(['date']).date.count().reset_index(name='sales')

# %%
train = all_cat_df[0:550]
valid = all_cat_df[550:]

# %%
X_train,y_train = create_features(train,'sales')
X_valid,y_valid = create_features(valid,'sales')
# Out:
# /var/folders/mb/w9_4bn093gbdkrx6gk7v40040000gn/T/ipykernel_10454/3942384757.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_week']=df['date'].dt.day_of_week
# /var/folders/mb/w9_4bn093gbdkrx6gk7v40040000gn/T/ipykernel_10454/3942384757.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter']=df.date.dt.quarter
# /var/folders/mb/w9_4bn093gbdkrx6gk7v40040000gn/T/ipykernel_10454/3942384757.py:4: SettingWithCopyWarning:
# ...

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 550 entries, 0 to 549
# Series name: sales
# Non-Null Count  Dtype
# --------------  -----
# 550 non-null    int64
# dtypes: int64(1)
# memory usage: 4.4 KB

# %%
from xgboost import XGBRegressor

# %%
XGB_allcat = XGBRegressor(n_estimators = 100)
XGB_allcat.fit(X_train,y_train,eval_metric = 'mae')
# Out:
# /Users/sviat/SMART/SMART/.venv/lib/python3.9/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
# ...

# %%
y_predict = XGB_allcat.predict(X_valid)

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(train['date'],train['sales'], c='#004a8f')
ax.plot(valid['date'],valid['sales'], c='#91aac9',linewidth=0.8)
ax.plot(valid['date'],y_predict,c='red',linewidth=0.8)
ax.legend(["train",'valid','xgboost'])
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(valid['date'],valid['sales'], c='#91aac9',linewidth=0.8)
ax.plot(valid['date'],y_predict,c='red',linewidth=0.8)
ax.legend(['valid','xgboost'])
plt.show()

# %% [markdown]
# ### prediction for next 7 days

# %%
test = pd.date_range(start=all_cat_df['date'].iloc[-1],periods=7)
test = pd.DataFrame(test,columns=['date'])
X_test = create_features(test)

# %%
y_test = XGB_allcat.predict(X_test)
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(train['date'],train['sales'], c='#004a8f')
ax.plot(valid['date'],valid['sales'], c='#91aac9',linewidth=0.8)
ax.plot(test['date'],y_test,c='red',linewidth=0.8)
ax.legend(["train",'valid','xgboost'])
plt.show()

# %%
ig,ax = plt.subplots(figsize=(10,5))
ax.plot(test['date'],y_test,c='red',linewidth=0.8)
ax.legend(['xgboost'])
plt.show()

# %% [markdown]
# ## ARIMA for single product category

# %%
single_cat_df  = df[df['product_category_name']=='esporte_lazer']
single_cat_df = single_cat_df.groupby(['date']).date.count().reset_index(name='sales')
single_cat_df = single_cat_df[single_cat_df['date'].dt.year!=2016]
single_cat_df
# Out:
#           date  sales
# 7   2017-01-11      1
# 8   2017-01-12      1
# 9   2017-01-13      1
# 10  2017-01-14      3
# 11  2017-01-16      1
# ..         ...    ...
# 589 2018-08-25      4
# 590 2018-08-26      4
# 591 2018-08-27     10
# 592 2018-08-28      8
# 593 2018-08-29      1
#
# [587 rows x 2 columns]

# %%
single_cat_df.columns=['date','sales']
# set data as index
single_cat_df.index = pd.to_datetime(single_cat_df['date'], format="%Y-%m-%d")

# remove data attribute that is repeated
single_cat_df.drop('date', axis=1, inplace=True)

# %%
single_cat_df.head()
# Out:
#             sales
# date
# 2017-01-11      1
# 2017-01-12      1
# 2017-01-13      1
# 2017-01-14      3
# 2017-01-16      1

# %%
single_cat_df = single_cat_df.resample('D').ffill()
single_cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 596 entries, 2017-01-11 to 2018-08-29
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sales   596 non-null    int64
# dtypes: int64(1)
# memory usage: 9.3 KB

# %%
X_single = single_cat_df.sales
result = adfuller(X_single)
print("ADF")
print("statisical test",result[0])
print('p-value',result[1])
# Out:
# ADF
# statisical test -2.913255810603812
# p-value 0.04382809938889915

# %% [markdown]
# p-value<0.05 - time series is stationary

# %%
train_single = single_cat_df[:-100]
valid_single = single_cat_df[-100:]

# %%
model_single = auto_arima(train_single,suppress_warnings=True)
model_single.fit(train_single)
forecast = model_single.predict(n_periods=len(valid_single))
forecast = pd.DataFrame(forecast,index = valid_single.index,columns=['Prediction'])

# %%
fig,ax = plt.subplots(figsize=(10,5))
train_single.plot(ax=ax, c='#004a8f')
valid_single.plot(ax=ax, c='#91aac9')
forecast.plot(ax=ax,c='red',linewidth=1.8)
ax.legend(["train",'valid','arima'])
plt.show()

# %%
model_single = auto_arima(single_cat_df,suppress_warnings=True)
model_single.fit(single_cat_df)
forecast = model_single.predict(n_periods=7)

# %%
fig,ax = plt.subplots(figsize=(10,5))
single_cat_df.plot(ax=ax, c='#004a8f')
forecast.plot(ax=ax,c='red',linewidth=1.8)
ax.legend(["train",'arima'])
plt.show()

# %% [markdown]
# ## ML for single product category

# %%
single_cat_df  = df[df['product_category_name']=='esporte_lazer']
single_cat_df = single_cat_df.groupby(['date']).date.count().reset_index(name='sales')

# %%
train = single_cat_df[0:-100]
valid = single_cat_df[-100:]

# %%
X_train,y_train = create_features(train,'sales')
X_valid,y_valid = create_features(valid,'sales')
# Out:
# /var/folders/mb/w9_4bn093gbdkrx6gk7v40040000gn/T/ipykernel_10454/2005360901.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_week']=df['date'].dt.day_of_week
# /var/folders/mb/w9_4bn093gbdkrx6gk7v40040000gn/T/ipykernel_10454/2005360901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter']=df.date.dt.quarter
# /var/folders/mb/w9_4bn093gbdkrx6gk7v40040000gn/T/ipykernel_10454/2005360901.py:4: SettingWithCopyWarning:
# ...

# %%
XGB_singlecat = XGBRegressor(n_estimators = 100)
XGB_singlecat.fit(X_train,y_train,eval_metric = 'mae')
# Out:
# /Users/sviat/SMART/SMART/.venv/lib/python3.9/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
# ...

# %%
y_predict = XGB_singlecat.predict(X_valid)

fig,ax = plt.subplots(figsize=(10,5))
ax.plot(train['date'],train['sales'], c='#004a8f')
ax.plot(valid['date'],valid['sales'], c='#91aac9',linewidth=0.8)
ax.plot(valid['date'],y_predict,c='red',linewidth=0.8)
ax.legend(["train",'valid','xgboost'])
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(valid['date'],valid['sales'], c='#91aac9',linewidth=0.8)
ax.plot(valid['date'],y_predict,c='red',linewidth=0.8)
ax.legend(['valid','xgboost'])
plt.show()

# %% [markdown]
# ### prediction for next 7 days

# %%
test = pd.date_range(start=single_cat_df['date'].iloc[-1],periods=7)
test = pd.DataFrame(test,columns=['date'])
X_test = create_features(test)

# %%
y_test = XGB_singlecat.predict(X_test)
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(train['date'],train['sales'], c='#004a8f')
ax.plot(valid['date'],valid['sales'], c='#91aac9',linewidth=0.8)
ax.plot(test['date'],y_test,c='red',linewidth=0.8)
ax.legend(["train",'valid','xgboost'])
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(test['date'],y_test,c='red',linewidth=0.8)
ax.legend(['xgboost'])
plt.show()
